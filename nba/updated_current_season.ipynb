# %%
import pandas as pd

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://www.google.com")
# Out:
# [WDM] - Downloading: 100%|██████████| 6.58M/6.58M [00:02<00:00, 2.53MB/s]

# %%
import time

player_stats_url = "https://www.basketball-reference.com/leagues/NBA_{}_per_game.html"
year = 2023
url = player_stats_url.format(year)

driver.get(url)
driver.execute_script("window.scrollTo(1,10000)")
time.sleep(2)

html = driver.page_source

# %%
with open("player/{}.html".format(year), "w+", encoding="utf-8") as f:
    f.write(html)

# %%
years = list(range(1991,2024))

# %%
from bs4 import BeautifulSoup

# %%
# save table while getting rid of all header rows
dfs = []
for year in years:
    with open("player/{}.html".format(year), encoding="utf-8") as f:
        page = f.read()
        
    soup = BeautifulSoup(page, "html.parser")
    tHeads = soup.find_all('tr', class_="thead")
    for thead in tHeads:
        thead.decompose()
    player_table = soup.find(id="per_game_stats")
    player = pd.read_html(str(player_table))[0]
    player["Year"] = year
    dfs.append(player)

# %%
players = pd.concat(dfs)

# %%
players
# Out:
#       Rk              Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  ORB  \
# 0      1      Alaa Abdelnaby  PF   22  POR  43   0   6.7  1.3   2.7  ...  0.6
# 1      2  Mahmoud Abdul-Rauf  PG   21  DEN  67  19  22.5  6.2  15.1  ...  0.5
# 2      3          Mark Acres   C   28  ORL  68   0  19.3  1.6   3.1  ...  2.1
# 3      4       Michael Adams  PG   28  DEN  66  66  35.5  8.5  21.5  ...  0.9
# 4      5        Mark Aguirre  SF   31  DET  78  13  25.7  5.4  11.7  ...  1.7
# ..   ...                 ...  ..  ...  ...  ..  ..   ...  ...   ...  ...  ...
# 486  485        Delon Wright  PG   30  WAS   4   0  22.8  2.5   6.0  ...  1.0
# 487  486  McKinley Wright IV  PG   24  DAL   2   0   4.0  0.5   2.0  ...  1.0
# 488  487      Thaddeus Young  PF   34  TOR  29   9  17.5  2.3   4.2  ...  1.8
# 489  488          Trae Young  PG   24  ATL  29  29  35.8  8.8  21.3  ...  0.8
# 490  489         Ivica Zubac   C   25  LAC  31  31  29.3  3.9   6.3  ...  3.3
#
#      DRB   TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0    1.4   2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1    1.3   1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2    3.2   5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3    3.0   3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4    3.1   4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
# ..   ...   ...   ...  ...  ...  ...  ...   ...   ...
# 486  1.5   2.5   3.3  2.8  1.0  1.0  1.3   6.5  2023
# 487  0.5   1.5   1.5  0.5  0.0  0.0  0.0   1.0  2023
# 488  2.1   3.9   1.8  1.1  0.1  0.8  1.9   5.1  2023
# 489  2.1   2.9   9.8  0.7  0.1  3.9  1.4  27.6  2023
# 490  7.5  10.7   1.1  0.4  1.5  2.1  3.2   9.9  2023
#
# [18689 rows x 31 columns]

# %%
players.to_csv("players.csv")

# %%
team_stats_url = "https://www.basketball-reference.com/leagues/NBA_{}_standings.html"

# %%
import requests
year = 2023
url = team_stats_url.format(year)
data = requests.get(url)

with open("team/{}.html".format(year), "w+", encoding="utf-8") as f:
    f.write(data.text)

# %%
dfs = []
for year in years:
    with open("team/{}.html".format(year), encoding="utf-8") as f:
        page = f.read()

    soup = BeautifulSoup(page, "html.parser")
    tHeads = soup.find_all('tr', class_="thead")
    for thead in tHeads:
        thead.decompose()
    team_table = soup.find(id="divs_standings_E")
    team = pd.read_html(str(team_table))[0]
    team["Year"] = year
    team["Team"] = team["Eastern Conference"]
    del team["Eastern Conference"]
    dfs.append(team)

    soup = BeautifulSoup(page, "html.parser")
    tHeads = soup.find_all('tr', class_="thead")
    for thead in tHeads:
        thead.decompose()
    team_table = soup.find(id="divs_standings_W")
    team = pd.read_html(str(team_table))[0]
    team["Year"] = year
    team["Team"] = team["Western Conference"]
    del team["Western Conference"]
    dfs.append(team)

# %%
teams = pd.concat(dfs)

# %%
teams
# Out:
#      W   L   W/L%    GB   PS/G   PA/G   SRS  Year                      Team
# 0   56  26  0.683     —  111.5  105.7  5.22  1991           Boston Celtics*
# 1   44  38  0.537  12.0  105.4  105.6 -0.39  1991       Philadelphia 76ers*
# 2   39  43  0.476  17.0  103.1  103.3 -0.43  1991          New York Knicks*
# 3   30  52  0.366  26.0  101.4  106.4 -4.84  1991        Washington Bullets
# 4   26  56  0.317  30.0  102.9  107.5 -4.53  1991           New Jersey Nets
# ..  ..  ..    ...   ...    ...    ...   ...   ...                       ...
# 10  19  11  0.633     —  115.4  111.2  4.00  2023     Memphis Grizzlies (2)
# 11  18  12  0.600   1.0  117.3  112.5  4.82  2023  New Orleans Pelicans (3)
# 12  16  16  0.500   4.0  110.9  109.5  2.38  2023      Dallas Mavericks (9)
# 13  10  20  0.333   9.0  110.3  119.5 -9.24  2023    San Antonio Spurs (14)
# 14   9  22  0.290  10.5  109.5  115.4 -5.71  2023      Houston Rockets (15)
#
# [966 rows x 9 columns]

# %%
teams.to_csv("teams.csv")

# %%
driver.quit()

# %%
players = pd.read_csv("players.csv")

# %%
players
# Out:
#        Unnamed: 0   Rk              Player Pos  Age   Tm   G  GS    MP   FG  \
# 0               0    1      Alaa Abdelnaby  PF   22  POR  43   0   6.7  1.3
# 1               1    2  Mahmoud Abdul-Rauf  PG   21  DEN  67  19  22.5  6.2
# 2               2    3          Mark Acres   C   28  ORL  68   0  19.3  1.6
# 3               3    4       Michael Adams  PG   28  DEN  66  66  35.5  8.5
# 4               4    5        Mark Aguirre  SF   31  DET  78  13  25.7  5.4
# ...           ...  ...                 ...  ..  ...  ...  ..  ..   ...  ...
# 18684         486  485        Delon Wright  PG   30  WAS   4   0  22.8  2.5
# 18685         487  486  McKinley Wright IV  PG   24  DAL   2   0   4.0  0.5
# 18686         488  487      Thaddeus Young  PF   34  TOR  29   9  17.5  2.3
# 18687         489  488          Trae Young  PG   24  ATL  29  29  35.8  8.8
# 18688         490  489         Ivica Zubac   C   25  LAC  31  31  29.3  3.9
#
#        ...  ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0      ...  0.6  1.4   2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1      ...  0.5  1.3   1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2      ...  2.1  3.2   5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3      ...  0.9  3.0   3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4      ...  1.7  3.1   4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
# ...    ...  ...  ...   ...   ...  ...  ...  ...  ...   ...   ...
# 18684  ...  1.0  1.5   2.5   3.3  2.8  1.0  1.0  1.3   6.5  2023
# 18685  ...  1.0  0.5   1.5   1.5  0.5  0.0  0.0  0.0   1.0  2023
# 18686  ...  1.8  2.1   3.9   1.8  1.1  0.1  0.8  1.9   5.1  2023
# 18687  ...  0.8  2.1   2.9   9.8  0.7  0.1  3.9  1.4  27.6  2023
# 18688  ...  3.3  7.5  10.7   1.1  0.4  1.5  2.1  3.2   9.9  2023
#
# [18689 rows x 32 columns]

# %%
del players["Unnamed: 0"]
del players["Rk"]

# %%
players.head()
# Out:
#                Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  ORB  \
# 0      Alaa Abdelnaby  PF   22  POR  43   0   6.7  1.3   2.7  0.474  ...  0.6
# 1  Mahmoud Abdul-Rauf  PG   21  DEN  67  19  22.5  6.2  15.1  0.413  ...  0.5
# 2          Mark Acres   C   28  ORL  68   0  19.3  1.6   3.1  0.509  ...  2.1
# 3       Michael Adams  PG   28  DEN  66  66  35.5  8.5  21.5  0.394  ...  0.9
# 4        Mark Aguirre  SF   31  DET  78  13  25.7  5.4  11.7  0.462  ...  1.7
#
#    DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0  1.4  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1  1.3  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2  3.2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3  3.0  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4  3.1  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
#
# [5 rows x 30 columns]

# %%
players["Player"] = players["Player"].str.replace("*","", regex=False)

# %%
def single_row(df):
    if df.shape[0]==1:
        return df
    else:
        row = df[df["Tm"] == "TOT"]
        row["Tm"] = df.iloc[-1,:]["Tm"]
        return row
    
players = players.groupby(["Player", "Year"]).apply(single_row)

# %%
players.index = players.index.droplevel()
players.index = players.index.droplevel()

# %%
players
# Out:
#               Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  ORB  \
# 159       A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...  2.5
# 609       A.C. Green  PF   28  LAL  82  53  35.4  4.7   9.8  0.476  ...  3.7
# 1051      A.C. Green  PF   29  LAL  82  55  34.4  4.6   8.6  0.537  ...  3.5
# 1519      A.C. Green  PF   30  PHO  82  55  34.5  5.7  11.3  0.502  ...  3.4
# 1988      A.C. Green  SF   31  PHO  82  52  32.8  3.8   7.5  0.504  ...  2.4
# ...              ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...  ...
# 5866  Željko Rebrača   C   29  DET  74   4  15.9  2.6   5.1  0.505  ...  1.1
# 6347  Željko Rebrača   C   30  DET  30  12  16.3  2.7   4.8  0.552  ...  0.9
# 6907  Željko Rebrača   C   31  ATL  24   2  11.4  1.4   3.2  0.442  ...  1.0
# 7485  Željko Rebrača   C   32  LAC  58   2  16.0  2.3   4.0  0.568  ...  0.8
# 8057  Željko Rebrača   C   33  LAC  29   2  14.2  1.8   3.3  0.542  ...  0.4
#
#       DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 159   3.8  6.3  0.9  0.7  0.3  1.2  1.4   9.1  1991
# 609   5.6  9.3  1.4  1.1  0.4  1.4  1.7  13.6  1992
# 1051  5.2  8.7  1.4  1.1  0.5  1.4  1.8  12.8  1993
# 1519  5.8  9.2  1.7  0.9  0.5  1.2  1.7  14.7  1994
# 1988  5.8  8.2  1.5  0.7  0.4  1.4  1.8  11.2  1995
# ...   ...  ...  ...  ...  ...  ...  ...   ...   ...
# 5866  2.8  3.9  0.5  0.4  1.0  1.1  2.6   6.9  2002
# 6347  2.2  3.1  0.3  0.2  0.6  1.0  2.6   6.6  2003
# 6907  1.5  2.4  0.3  0.2  0.5  0.7  2.2   3.8  2004
# 7485  2.3  3.2  0.4  0.2  0.7  0.8  2.2   5.8  2005
# 8057  1.8  2.2  0.3  0.2  0.7  0.8  2.0   4.7  2006
#
# [15186 rows x 30 columns]

# %%
teams = pd.read_csv("teams.csv")

# %%
teams.head(30)
# Out:
#     Unnamed: 0   W   L   W/L%    GB   PS/G   PA/G    SRS  Year  \
# 0            0  56  26  0.683     —  111.5  105.7   5.22  1991
# 1            1  44  38  0.537  12.0  105.4  105.6  -0.39  1991
# 2            2  39  43  0.476  17.0  103.1  103.3  -0.43  1991
# 3            3  30  52  0.366  26.0  101.4  106.4  -4.84  1991
# 4            4  26  56  0.317  30.0  102.9  107.5  -4.53  1991
# 5            5  24  58  0.293  32.0  101.8  107.8  -5.91  1991
# 6            6  61  21  0.744     —  110.0  101.0   8.57  1991
# 7            7  50  32  0.610  11.0  100.1   96.8   3.08  1991
# 8            8  48  34  0.585  13.0  106.4  104.0   2.33  1991
# 9            9  43  39  0.524  18.0  109.8  109.0   0.72  1991
# 10          10  41  41  0.500  20.0  111.7  112.1  -0.37  1991
# 11          11  33  49  0.402  28.0  101.7  104.2  -2.33  1991
# 12          12  26  56  0.317  35.0  102.8  108.0  -4.95  1991
# 13           0  55  27  0.671     —  107.1  102.6   4.30  1991
# 14           1  54  28  0.659   1.0  104.0  100.7   3.18  1991
# 15           2  52  30  0.634   3.0  106.7  103.2   3.27  1991
# 16           3  31  51  0.378  24.0  105.9  109.9  -3.79  1991
# 17           4  29  53  0.354  26.0   99.6  103.5  -3.75  1991
# 18           5  28  54  0.341  27.0   99.9  104.5  -4.27  1991
# 19           6  20  62  0.244  35.0  119.9  130.8 -10.31  1991
# 20           7  63  19  0.768     —  114.7  106.0   8.47  1991
# 21           8  58  24  0.707   5.0  106.3   99.6   6.73  1991
# 22           9  55  27  0.671   8.0  114.0  107.5   6.49  1991
# 23          10  44  38  0.537  19.0  116.6  115.0   1.72  1991
# 24          11  41  41  0.500  22.0  106.6  105.4   1.31  1991
# 25          12  31  51  0.378  32.0  103.5  107.0  -3.16  1991
# 26          13  25  57  0.305  38.0   96.7  103.5  -6.27  1991
# 27           0  51  31  0.622     —  106.6  103.0   3.41  1992
# 28           1  51  31  0.622     —  101.6   97.7   3.67  1992
# 29           2  40  42  0.488  11.0  105.4  107.1  -1.54  1992
#
#                        Team
# 0           Boston Celtics*
# 1       Philadelphia 76ers*
# 2          New York Knicks*
# 3        Washington Bullets
# 4           New Jersey Nets
# 5                Miami Heat
# 6            Chicago Bulls*
# 7          Detroit Pistons*
# 8          Milwaukee Bucks*
# 9            Atlanta Hawks*
# 10          Indiana Pacers*
# 11      Cleveland Cavaliers
# 12        Charlotte Hornets
# 13       San Antonio Spurs*
# 14               Utah Jazz*
# 15         Houston Rockets*
# 16            Orlando Magic
# 17   Minnesota Timberwolves
# 18         Dallas Mavericks
# 19           Denver Nuggets
# 20  Portland Trail Blazers*
# 21      Los Angeles Lakers*
# 22            Phoenix Suns*
# 23   Golden State Warriors*
# 24     Seattle SuperSonics*
# 25     Los Angeles Clippers
# 26         Sacramento Kings
# 27          Boston Celtics*
# 28         New York Knicks*
# 29         New Jersey Nets*

# %%
teams["Team"] = teams["Team"].str.replace("*", "", regex=False)

# %%
teams["Team"].unique()
# Out:
# array(['Boston Celtics', 'Philadelphia 76ers', 'New York Knicks',
#        'Washington Bullets', 'New Jersey Nets', 'Miami Heat',
#        'Chicago Bulls', 'Detroit Pistons', 'Milwaukee Bucks',
#        'Atlanta Hawks', 'Indiana Pacers', 'Cleveland Cavaliers',
#        'Charlotte Hornets', 'San Antonio Spurs', 'Utah Jazz',
#        'Houston Rockets', 'Orlando Magic', 'Minnesota Timberwolves',
#        'Dallas Mavericks', 'Denver Nuggets', 'Portland Trail Blazers',
#        'Los Angeles Lakers', 'Phoenix Suns', 'Golden State Warriors',
#        'Seattle SuperSonics', 'Los Angeles Clippers', 'Sacramento Kings',
#        'Toronto Raptors', 'Vancouver Grizzlies', 'Washington Wizards',
#        'Memphis Grizzlies', 'New Orleans Hornets', 'Charlotte Bobcats',
#        'New Orleans/Oklahoma City Hornets', 'Oklahoma City Thunder',
#        'Brooklyn Nets', 'New Orleans Pelicans', 'Boston Celtics\xa0(2)',
#        'Brooklyn Nets\xa0(4)', 'Philadelphia 76ers\xa0(5)',
#        'New York Knicks\xa0(6)', 'Toronto Raptors\xa0(10)',
#        'Milwaukee Bucks\xa0(1)', 'Cleveland Cavaliers\xa0(3)',
#        'Indiana Pacers\xa0(8)', 'Chicago Bulls\xa0(11)',
#        'Detroit Pistons\xa0(15)', 'Miami Heat\xa0(7)',
#        'Atlanta Hawks\xa0(9)', 'Washington Wizards\xa0(12)',
#        'Orlando Magic\xa0(13)', 'Charlotte Hornets\xa0(14)',
#        'Denver Nuggets\xa0(1)', 'Portland Trail Blazers\xa0(7)',
#        'Utah Jazz\xa0(8)', 'Minnesota Timberwolves\xa0(10)',
#        'Oklahoma City Thunder\xa0(12)', 'Phoenix Suns\xa0(4)',
#        'Los Angeles Clippers\xa0(5)', 'Sacramento Kings\xa0(6)',
#        'Golden State Warriors\xa0(11)', 'Los Angeles Lakers\xa0(13)',
#        'Memphis Grizzlies\xa0(2)', 'New Orleans Pelicans\xa0(3)',
#        'Dallas Mavericks\xa0(9)', 'San Antonio Spurs\xa0(14)',
#        'Houston Rockets\xa0(15)'], dtype=object)

# %%
teams["Team"] = teams["Team"].str.replace("\xa0([^)]*)", "", regex=True)

# %%
teams
# Out:
#      Unnamed: 0   W   L   W/L%    GB   PS/G   PA/G   SRS  Year  \
# 0             0  56  26  0.683     —  111.5  105.7  5.22  1991
# 1             1  44  38  0.537  12.0  105.4  105.6 -0.39  1991
# 2             2  39  43  0.476  17.0  103.1  103.3 -0.43  1991
# 3             3  30  52  0.366  26.0  101.4  106.4 -4.84  1991
# 4             4  26  56  0.317  30.0  102.9  107.5 -4.53  1991
# ..          ...  ..  ..    ...   ...    ...    ...   ...   ...
# 961          10  19  11  0.633     —  115.4  111.2  4.00  2023
# 962          11  18  12  0.600   1.0  117.3  112.5  4.82  2023
# 963          12  16  16  0.500   4.0  110.9  109.5  2.38  2023
# 964          13  10  20  0.333   9.0  110.3  119.5 -9.24  2023
# 965          14   9  22  0.290  10.5  109.5  115.4 -5.71  2023
#
#                       Team
# 0           Boston Celtics
# 1       Philadelphia 76ers
# 2          New York Knicks
# 3       Washington Bullets
# 4          New Jersey Nets
# ..                     ...
# 961     Memphis Grizzlies)
# 962  New Orleans Pelicans)
# 963      Dallas Mavericks)
# 964     San Antonio Spurs)
# 965       Houston Rockets)
#
# [966 rows x 10 columns]

# %%
teams["Team"].unique()
# Out:
# array(['Boston Celtics', 'Philadelphia 76ers', 'New York Knicks',
#        'Washington Bullets', 'New Jersey Nets', 'Miami Heat',
#        'Chicago Bulls', 'Detroit Pistons', 'Milwaukee Bucks',
#        'Atlanta Hawks', 'Indiana Pacers', 'Cleveland Cavaliers',
#        'Charlotte Hornets', 'San Antonio Spurs', 'Utah Jazz',
#        'Houston Rockets', 'Orlando Magic', 'Minnesota Timberwolves',
#        'Dallas Mavericks', 'Denver Nuggets', 'Portland Trail Blazers',
#        'Los Angeles Lakers', 'Phoenix Suns', 'Golden State Warriors',
#        'Seattle SuperSonics', 'Los Angeles Clippers', 'Sacramento Kings',
#        'Toronto Raptors', 'Vancouver Grizzlies', 'Washington Wizards',
#        'Memphis Grizzlies', 'New Orleans Hornets', 'Charlotte Bobcats',
#        'New Orleans/Oklahoma City Hornets', 'Oklahoma City Thunder',
#        'Brooklyn Nets', 'New Orleans Pelicans', 'Boston Celtics)',
#        'Brooklyn Nets)', 'Philadelphia 76ers)', 'New York Knicks)',
#        'Toronto Raptors)', 'Milwaukee Bucks)', 'Cleveland Cavaliers)',
#        'Indiana Pacers)', 'Chicago Bulls)', 'Detroit Pistons)',
#        'Miami Heat)', 'Atlanta Hawks)', 'Washington Wizards)',
#        'Orlando Magic)', 'Charlotte Hornets)', 'Denver Nuggets)',
#        'Portland Trail Blazers)', 'Utah Jazz)', 'Minnesota Timberwolves)',
#        'Oklahoma City Thunder)', 'Phoenix Suns)', 'Los Angeles Clippers)',
#        'Sacramento Kings)', 'Golden State Warriors)',
#        'Los Angeles Lakers)', 'Memphis Grizzlies)',
#        'New Orleans Pelicans)', 'Dallas Mavericks)', 'San Antonio Spurs)',
#        'Houston Rockets)'], dtype=object)

# %%
teams["Team"] = teams["Team"].str.replace(")", "", regex=False)

# %%
teams
# Out:
#      Unnamed: 0   W   L   W/L%    GB   PS/G   PA/G   SRS  Year  \
# 0             0  56  26  0.683     —  111.5  105.7  5.22  1991
# 1             1  44  38  0.537  12.0  105.4  105.6 -0.39  1991
# 2             2  39  43  0.476  17.0  103.1  103.3 -0.43  1991
# 3             3  30  52  0.366  26.0  101.4  106.4 -4.84  1991
# 4             4  26  56  0.317  30.0  102.9  107.5 -4.53  1991
# ..          ...  ..  ..    ...   ...    ...    ...   ...   ...
# 961          10  19  11  0.633     —  115.4  111.2  4.00  2023
# 962          11  18  12  0.600   1.0  117.3  112.5  4.82  2023
# 963          12  16  16  0.500   4.0  110.9  109.5  2.38  2023
# 964          13  10  20  0.333   9.0  110.3  119.5 -9.24  2023
# 965          14   9  22  0.290  10.5  109.5  115.4 -5.71  2023
#
#                      Team
# 0          Boston Celtics
# 1      Philadelphia 76ers
# 2         New York Knicks
# 3      Washington Bullets
# 4         New Jersey Nets
# ..                    ...
# 961     Memphis Grizzlies
# 962  New Orleans Pelicans
# 963      Dallas Mavericks
# 964     San Antonio Spurs
# 965       Houston Rockets
#
# [966 rows x 10 columns]

# %%
teams["Team"].unique()
# Out:
# array(['Boston Celtics', 'Philadelphia 76ers', 'New York Knicks',
#        'Washington Bullets', 'New Jersey Nets', 'Miami Heat',
#        'Chicago Bulls', 'Detroit Pistons', 'Milwaukee Bucks',
#        'Atlanta Hawks', 'Indiana Pacers', 'Cleveland Cavaliers',
#        'Charlotte Hornets', 'San Antonio Spurs', 'Utah Jazz',
#        'Houston Rockets', 'Orlando Magic', 'Minnesota Timberwolves',
#        'Dallas Mavericks', 'Denver Nuggets', 'Portland Trail Blazers',
#        'Los Angeles Lakers', 'Phoenix Suns', 'Golden State Warriors',
#        'Seattle SuperSonics', 'Los Angeles Clippers', 'Sacramento Kings',
#        'Toronto Raptors', 'Vancouver Grizzlies', 'Washington Wizards',
#        'Memphis Grizzlies', 'New Orleans Hornets', 'Charlotte Bobcats',
#        'New Orleans/Oklahoma City Hornets', 'Oklahoma City Thunder',
#        'Brooklyn Nets', 'New Orleans Pelicans'], dtype=object)

# %%
teams["GB"] = teams["GB"].str.replace("—", "0")

# %%
teams
# Out:
#      Unnamed: 0   W   L   W/L%    GB   PS/G   PA/G   SRS  Year  \
# 0             0  56  26  0.683     0  111.5  105.7  5.22  1991
# 1             1  44  38  0.537  12.0  105.4  105.6 -0.39  1991
# 2             2  39  43  0.476  17.0  103.1  103.3 -0.43  1991
# 3             3  30  52  0.366  26.0  101.4  106.4 -4.84  1991
# 4             4  26  56  0.317  30.0  102.9  107.5 -4.53  1991
# ..          ...  ..  ..    ...   ...    ...    ...   ...   ...
# 961          10  19  11  0.633     0  115.4  111.2  4.00  2023
# 962          11  18  12  0.600   1.0  117.3  112.5  4.82  2023
# 963          12  16  16  0.500   4.0  110.9  109.5  2.38  2023
# 964          13  10  20  0.333   9.0  110.3  119.5 -9.24  2023
# 965          14   9  22  0.290  10.5  109.5  115.4 -5.71  2023
#
#                      Team
# 0          Boston Celtics
# 1      Philadelphia 76ers
# 2         New York Knicks
# 3      Washington Bullets
# 4         New Jersey Nets
# ..                    ...
# 961     Memphis Grizzlies
# 962  New Orleans Pelicans
# 963      Dallas Mavericks
# 964     San Antonio Spurs
# 965       Houston Rockets
#
# [966 rows x 10 columns]

# %%
read_file = pd.read_csv(r'C:\Users\brian\nicknames.txt')
read_file.to_csv (r'C:\Users\brian\nicknames.csv', index=None)

# %%
nicknames = {}

with open("nicknames.csv") as f:
    lines = f.readlines()
    for line in lines[1:]:
        abbrev, name = line.replace("\n", "").split(",")
        nicknames[abbrev] = name

# %%
players["Team"] = players["Tm"].map(nicknames)

# %%
players
# Out:
#               Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  DRB  \
# 159       A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...  3.8
# 609       A.C. Green  PF   28  LAL  82  53  35.4  4.7   9.8  0.476  ...  5.6
# 1051      A.C. Green  PF   29  LAL  82  55  34.4  4.6   8.6  0.537  ...  5.2
# 1519      A.C. Green  PF   30  PHO  82  55  34.5  5.7  11.3  0.502  ...  5.8
# 1988      A.C. Green  SF   31  PHO  82  52  32.8  3.8   7.5  0.504  ...  5.8
# ...              ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...  ...
# 5866  Željko Rebrača   C   29  DET  74   4  15.9  2.6   5.1  0.505  ...  2.8
# 6347  Željko Rebrača   C   30  DET  30  12  16.3  2.7   4.8  0.552  ...  2.2
# 6907  Željko Rebrača   C   31  ATL  24   2  11.4  1.4   3.2  0.442  ...  1.5
# 7485  Željko Rebrača   C   32  LAC  58   2  16.0  2.3   4.0  0.568  ...  2.3
# 8057  Željko Rebrača   C   33  LAC  29   2  14.2  1.8   3.3  0.542  ...  1.8
#
#       TRB  AST  STL  BLK  TOV   PF   PTS  Year                  Team
# 159   6.3  0.9  0.7  0.3  1.2  1.4   9.1  1991    Los Angeles Lakers
# 609   9.3  1.4  1.1  0.4  1.4  1.7  13.6  1992    Los Angeles Lakers
# 1051  8.7  1.4  1.1  0.5  1.4  1.8  12.8  1993    Los Angeles Lakers
# 1519  9.2  1.7  0.9  0.5  1.2  1.7  14.7  1994          Phoenix Suns
# 1988  8.2  1.5  0.7  0.4  1.4  1.8  11.2  1995          Phoenix Suns
# ...   ...  ...  ...  ...  ...  ...   ...   ...                   ...
# 5866  3.9  0.5  0.4  1.0  1.1  2.6   6.9  2002       Detroit Pistons
# 6347  3.1  0.3  0.2  0.6  1.0  2.6   6.6  2003       Detroit Pistons
# 6907  2.4  0.3  0.2  0.5  0.7  2.2   3.8  2004         Atlanta Hawks
# 7485  3.2  0.4  0.2  0.7  0.8  2.2   5.8  2005  Los Angeles Clippers
# 8057  2.2  0.3  0.2  0.7  0.8  2.0   4.7  2006  Los Angeles Clippers
#
# [15186 rows x 31 columns]

# %%
players.to_csv("players.csv")

# %%
teams.to_csv("teams.csv")
